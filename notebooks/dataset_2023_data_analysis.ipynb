# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %% [markdown]
# Загрузим датасет

# %%
input_file = Path.home() / "apartment-price-prediction" / "data" / "processed" / "2023" / "moscow_2023.csv"

df = pd.read_csv(input_file, sep=',')

# %% [markdown]
# Проанализируем датасет

# %%
df.describe()
# Out:
#               Price  Minutes to metro  Number of rooms          Area  \
# count  1.611300e+04      16113.000000     16113.000000  16113.000000
# mean   4.798348e+07         12.535344         2.222057     81.922181
# std    9.573436e+07          6.790625         1.671017     78.197326
# min    1.150000e+06          0.000000         0.000000      6.000000
# 25%    1.020000e+07          7.000000         1.000000     38.800000
# 50%    1.595000e+07         12.000000         2.000000     60.000000
# 75%    4.000000e+07         17.000000         3.000000     93.300000
# max    2.455020e+09         60.000000        12.000000   1117.000000
#
#         Living area  Kitchen area         Floor  Number of floors
# count  16113.000000  16113.000000  16113.000000      16113.000000
# mean      43.884596     13.594830      9.119531         16.421833
# std       43.645793      8.625711      8.272039         11.254795
# min        2.000000      1.000000      1.000000          1.000000
# ...

# %% [markdown]
# Посмотрим, сколько всего данных той или иной категории

# %%
df["Number of rooms"].value_counts()
# Out:
# Number of rooms
# 2.0     6342
# 1.0     5141
# 3.0     3814
# 0.0     3731
# 4.0     1957
# 5.0      993
# 6.0      652
# 7.0       27
# 8.0       10
# 10.0       5
# 9.0        3
# 12.0       1
# Name: count, dtype: int64

# %%
df["Apartment type"].value_counts()
# Out:
# Apartment type
# Secondary       13152
# New building     9524
# Name: count, dtype: int64

# %%
df["Renovation"].value_counts()
# Out:
# Renovation
# Cosmetic                     12788
# European-style renovation     3666
# Without renovation            3198
# Designer                      3024
# Name: count, dtype: int64
